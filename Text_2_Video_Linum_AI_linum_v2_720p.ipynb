# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.9.28 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !git clone https://github.com/Linum-AI/linum-v2.git
# Out:
# Cloning into 'linum-v2'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 87 (delta 35), reused 53 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (87/87), 2.96 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd linum-v2
# !uv sync
# Out:
# /content/linum-v2
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 54 packages in 1ms
# Prepared 51 packages in 1m 33s
# Installed 51 packages in 722ms
#  + av==16.1.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + diffusers==0.34.0
#  + einops==0.8.1
#  + filelock==3.20.3
#  + fsspec==2026.1.0
#  + hf-xet==1.2.0
#  + huggingface-hub==0.36.0
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + jinja2==3.1.6
#  + linum-v2==1.0.0 (from file:///content/linum-v2)
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + ninja==1.13.0
#  + numpy==2.1.1
#  + nvidia-cublas-cu12==12.8.3.14
#  + nvidia-cuda-cupti-cu12==12.8.57
#  + nvidia-cuda-nvrtc-cu12==12.8.61
#  + nvidia-cuda-runtime-cu12==12.8.57
#  + nvidia-cudnn-cu12==9.7.1.26
#  + nvidia-cufft-cu12==11.3.3.41
#  + nvidia-cufile-cu12==1.13.0.11
#  + nvidia-curand-cu12==10.3.9.55
#  + nvidia-cusolver-cu12==11.7.2.55
#  + nvidia-cusparse-cu12==12.5.7.53
# ...

# %%
# !uv run python generate_video.py \
    --prompt "In a charming hand-drawn 2D animation style, I am a fruit and a vegetable with a human eating me" \
    --output human_eating.mp4 \
    --seed 20 \
    --cfg 7.0
# Out:
# ...
# Repository: Linum-AI/linum-v2-720p
#   - Downloading DiT model...
# dit/720p.safetensors: 100% 8.03G/8.03G [01:16<00:00, 105MB/s]
#   - Downloading VAE...
# vae/vae.safetensors: 100% 508M/508M [00:05<00:00, 93.4MB/s]
#   - Downloading T5 encoder...
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# config.json: 100% 782/782 [00:00<00:00, 6.61MB/s]
# Fetching 4 files:  25% 1/4 [00:00<00:01,  2.33it/s]
# model.safetensors.index.json: 19.9kB [00:00, 63.0MB/s]
#
# t5/text_encoder/model-00002-of-00002.saf(…):   0% 0.00/4.53G [00:00<?, ?B/s]
#
# t5/text_encoder/model-00001-of-00002.saf(…):   0% 0.00/4.99G [00:00<?, ?B/s]
# t5/text_encoder/model-00002-of-00002.saf(…):   0% 832k/4.53G [00:01<2:13:29, 565kB/s]
#
# t5/text_encoder/model-00001-of-00002.saf(…):   0% 587k/4.99G [00:02<5:34:53, 249kB/s]
# t5/text_encoder/model-00002-of-00002.saf(…):   0% 2.43M/4.53G [00:02<1:15:52, 994kB/s]
# t5/text_encoder/model-00002-of-00002.saf(…):   2% 69.5M/4.53G [00:06<06:17, 11.8MB/s]
# ...
